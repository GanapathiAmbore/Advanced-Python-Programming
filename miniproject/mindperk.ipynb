# %%
import requests

headers = {
    'authority': 'www.mindperk.com',
    'cache-control': 'max-age=0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://www.mindperk.com/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'PHPSESSID=b109551b92e5b5fa5d2a6b5565a75d3c',
}

response = requests.get('https://www.mindperk.com/product-author/zig-ziglar/', headers=headers)

# %%
from bs4 import BeautifulSoup as soup
page_soup=soup(response.text,'html.parser')

# %%
headings=page_soup.find_all('h2')

# %%
final_list=[]
for head in headings:
    temp_dict={}
    titles=head.text
    temp_dict['titles']=titles
    final_list.append(temp_dict)
print(final_list)
# Out:
# [{'titles': '5 Steps to Successful Selling – 1 audio CD'}, {'titles': 'A View from the TOP – audio CD or MP3'}, {'titles': 'Better Than Good – audio CDs'}, {'titles': 'Biscuits, Fleas, and Pump Handles – audio CD or MP3'}, {'titles': 'Born To Win – audio CD or MP3'}, {'titles': 'Born to Win Seminar Library – CDs & DVDs'}, {'titles': 'Changing the Picture – MP3 download'}, {'titles': 'Closes Closes Closes – DVD'}, {'titles': 'Conversation on Character – DVD'}, {'titles': 'Conversation on Character – MP3 download'}, {'titles': 'Courtship After Marriage – audio CDs'}, {'titles': 'Developing the Qualities of Success – MP3 download'}, {'titles': 'Embrace the Struggle – audio CD or MP3'}, {'titles': 'Goals – 2 audio CDs (basic version)'}, {'titles': 'Goals – DVD'}, {'titles': 'Goals: Set Them, Reach Them – audio CDs'}, {'titles': 'How to Be a Winner – audio CDs'}, {'titles': 'How to Get What You Want – audio CDs'}, {'titles': 'How to Stay Motivated – audio CD or MP3 package'}, {'titles': '
# ...

# %%
import pandas as pd
df=pd.DataFrame(final_list)
df.to_csv('zig Zigler.csv')

# %%
for num in range(1,21):
    url='http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-{}'.format(num)
    with open('naukri.txt','a') as file:
        file.write(url)
        file.write('\n')

# %%
file=open('naukri.txt','r')
file.read().replace('\n','')
# Out:
# 'http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-20http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-1http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-2http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-3http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-4http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-5http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-6http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-7http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-8http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-9http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-10http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-11http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-12http://naukri.com/python-developer-jobs-in-hyderabad-secunderabad-13http://naukri.com/python-developer-jobs-in-hyderabad-s
# ...

# %%
for num in range(1,10):
    smart_vidya_url='http://www.smartvidya.co.in/2017/10/mcqs-on-communication-{}.html'.format(num)
    print(smart_vidya_url)
# Out:
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-1.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-2.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-3.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-4.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-5.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-6.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-7.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-8.html
# http://www.smartvidya.co.in/2017/10/mcqs-on-communication-9.html

# %%
from bs4 import BeautifulSoup as soup
import requests

headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Referer': 'http://localhost:8888/',
    'Accept-Language': 'en-US,en;q=0.9',
    'If-None-Match': 'W/^\\^2c0428b6fc397f21c85559d1b5575227b46e517b703c44f3f82b5da120e39635^\\^',
    'If-Modified-Since': 'Fri, 02 Oct 2020 09:55:44 GMT',
}

response = requests.get('http://www.smartvidya.co.in/2017/10/mcqs-on-communication-9.html', headers=headers, verify=False)

# %%
response
# Out:
# <Response [200]>

# %%
page_soup=soup(response.text,'html.parser')

# %%
page_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v14.9 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Zig Ziglar - MindPerk</title>
# <meta content="Zig Ziglar is an exceptional speaker, in the fields of motivation, sales training, and attitude. He has life-changing ideas and solutions for you," name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://www.mindperk.com/product-author/zig-ziglar/" rel="canonical"/>
# <link href="https://www.mindperk.com/product-author/zig-ziglar/page/2/" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Zig Ziglar - MindPerk" property="og:title"/>
# ...

# %%
main_div=page_soup.find('div',{'dir':'ltr'})

# %%
main_div
