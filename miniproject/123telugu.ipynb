# %%
# Out:
#   File "<ipython-input-114-75943cb8a372>", line 15
#     'cookie': '__asc=c2274cb4174e7d8f78a400f9c39; __auc=c2274cb4174e7d8f78a400f9c39; _ga=GA1.2.1680526416.1601617591; _gid=GA1.2.583665928.1601617592; _gat_gtag_UA_149767057_1=1; _gat_gtag_UA_2039522_1=1; sc_is_visitor_unique=rx2763089.1601617611.EFE3F48EB4F84F52001995906B3C60A2.1.1.1.1.1.1.1.1.1; _gat=1; desktopPoweredLink06052020=https^%^3A^%^2F^%^2Fapp.ex.co^%^2Fstories^%^2Fitem^%^2F762b48f5-a935-45fe-ad13-bf4b3e8aba0d^%^3Futm_campaign^%^3DWatermark^%^26utm_source^%^3Dwatermark',
#             ^
# SyntaxError: invalid syntax

# %%
response.text
# Out:
# '\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  <!DOCTYPE html>\n<html lang="en">\n\n    <head>\n      <title>Orey Bujjiga Telugu  Movie Review | 123telugu.com</title>\n\n      \n          <meta name="description" content="Telugu cinema news, Telugu Movies Updates, Latest Movie reviews in Telugu, Telugu cinema reviews, telugu movie reviews, Tollywood, Box office collections, Telugu Movie show times, Theater List, telugu cinema tickets"/>\n\n          <meta name="keywords" content="Telugu cinema news, Telugu Movies Updates, Latest Movie reviews in Telugu, Telugu cinema reviews, telugu movie reviews, Telugu Actress Photos, Telugu Movie HQ Photos, Tollywood, Box office collections, Telugu Movie show times, Theater List, telugu cinema tickets" />\n\n\t\t  <script data-ad-client="ca-pub-9133154630895327" async src="https://pagead2.googlesyndication
# ...

# %%
from bs4 import BeautifulSoup as soup
page_soup=soup(response.text,'html.parser')

# %%
page_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Orey Bujjiga Telugu  Movie Review | 123telugu.com</title>
# <meta content="Telugu cinema news, Telugu Movies Updates, Latest Movie reviews in Telugu, Telugu cinema reviews, telugu movie reviews, Tollywood, Box office collections, Telugu Movie show times, Theater List, telugu cinema tickets" name="description"/>
# <meta content="Telugu cinema news, Telugu Movies Updates, Latest Movie reviews in Telugu, Telugu cinema reviews, telugu movie reviews, Telugu Actress Photos, Telugu Movie HQ Photos, Tollywood, Box office collections, Telugu Movie show times, Theater List, telugu cinema tickets" name="keywords"/>
# <script async="" data-ad-client="ca-pub-9133154630895327" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <meta content="https://www.123telugu.com/content/wp-content/themes/123telugu/images/logo.gif" property="og:image"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# ...

# %%
review=page_soup.find_all('p')

# %%
final_list=[]
temp_dict={}
for r in review:
    final=r.text.split(':')
    try:
        temp_dict[final[0].strip()]=final[1].strip()
    except Exception as e:
        print(e)
final_list.append(temp_dict)
print(final_list)
import pandas as pd
df=pd.DataFrame(final_list)
df
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# [{'Release date': 'October 1,2020', '123telugu.com Rating': '2.5/5\nReviewed by 123telugu Team', 'Starring': 'Raj Tarun, Malavika Nair, Hebah Patel', 'Director': 'Vijay Kumar Konda', 'Producer': 'K. K. Radhamohan', 'Music': 'Anup Rubens', 'Cinematography': 'I. Andrew', 'Editor': 'Prawin Pudi', 'Story': '', 'Verdict': '', 'Ad': 'Teluguruchi - Learn.. Cook.. Enjoy the Tasty food'}]
#      Release date               123telugu.com Rating  \
# ...

# %%
import requests

headers = {
    'authority': 'www.123telugu.com',
    'cache-control': 'max-age=0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://www.123telugu.com/reviews/orey-bujjiga-telugu-movie-review.html',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__auc=c2274cb4174e7d8f78a400f9c39; _ga=GA1.2.1680526416.1601617591; _gid=GA1.2.583665928.1601617592; desktopPoweredLink06052020=https^%^3A^%^2F^%^2Fapp.ex.co^%^2Fstories^%^2Fitem^%^2F762b48f5-a935-45fe-ad13-bf4b3e8aba0d^%^3Futm_campaign^%^3DWatermark^%^26utm_source^%^3Dwatermark; sc_is_visitor_unique=rx2763089.1601621316.EFE3F48EB4F84F52001995906B3C60A2.2.1.1.1.1.1.1.1.1; __asc=eb9657c1174e811d0a28e44e653',
}

response = requests.get('https://www.123telugu.com/reviews/nishabdham-telugu-movie-review.html', headers=headers)

# %%
response.text
# Out:
# '\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  <!DOCTYPE html>\n<html lang="en">\n\n    <head>\n      <title>Orey Bujjiga Telugu  Movie Review | 123telugu.com</title>\n\n      \n          <meta name="description" content="Telugu cinema news, Telugu Movies Updates, Latest Movie reviews in Telugu, Telugu cinema reviews, telugu movie reviews, Tollywood, Box office collections, Telugu Movie show times, Theater List, telugu cinema tickets"/>\n\n          <meta name="keywords" content="Telugu cinema news, Telugu Movies Updates, Latest Movie reviews in Telugu, Telugu cinema reviews, telugu movie reviews, Telugu Actress Photos, Telugu Movie HQ Photos, Tollywood, Box office collections, Telugu Movie show times, Theater List, telugu cinema tickets" />\n\n\t\t  <script data-ad-client="ca-pub-9133154630895327" async src="https://pagead2.googlesyndication
# ...

# %%
from bs4 import BeautifulSoup as soup
page_soup=soup(response.text,'html.parser')
