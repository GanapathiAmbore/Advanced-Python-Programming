# %%
from bs4 import BeautifulSoup as soup
import requests

headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Referer': 'http://localhost:8888/',
    'Accept-Language': 'en-US,en;q=0.9',
    'If-None-Match': 'W/^\\^2c0428b6fc397f21c85559d1b5575227b46e517b703c44f3f82b5da120e39635^\\^',
    'If-Modified-Since': 'Fri, 02 Oct 2020 09:55:44 GMT',
}

response = requests.get('http://www.smartvidya.co.in/2017/10/mcqs-on-communication-9.html', headers=headers, verify=False)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class=\'v2\' dir=\'ltr\' xmlns=\'http://www.w3.org/1999/xhtml\' xmlns:b=\'http://www.google.com/2005/gml/b\' xmlns:data=\'http://www.google.com/2005/gml/data\' xmlns:expr=\'http://www.google.com/2005/gml/expr\'>\n<head>\n<link href=\'https://www.blogger.com/static/v1/widgets/3416767676-css_bundle_v2.css\' rel=\'stylesheet\' type=\'text/css\'/>\n<meta charset=\'UTF-8\'/>\n<meta content=\'width=device-width, initial-scale=1.0\' name=\'viewport\'/>\n<meta content=\'text/html; charset=UTF-8\' http-equiv=\'Content-Type\'/>\n<meta content=\'blogger\' name=\'generator\'/>\n<link href=\'http://www.smartvidya.co.in/favicon.ico\' rel=\'icon\' type=\'image/x-icon\'/>\n<link href=\'http://www.smartvidya.co.in/2017/10/mcqs-on-communication-9.html\' rel=\'canonical\'/>\n<link rel="alternate" type="application/atom+xml" title="Smart Vidya - Atom" href="http://www.smartvidya.co.in/feeds/posts/default" />\n<link rel="alternate" type="application/rss+xml" title="Smart Vidya - R
# ...

# %%
from bs4 import BeautifulSoup as soup
page_soup=soup(response.text,'html.parser')
main_div=page_soup.find_all('div',{'class':'post-body entry-content'})

# %%
for question in main_div:
    print(question)
# Out:
# <div dir="ltr" style="text-align: left;" trbidi="on">
# <div style="text-align: justify;">
# <b style="font-family: arial; text-align: left;">1. The CBFC Certificate of ‘U’ means</b></div>
# <div class="MsoNormal" style="line-height: 24px;">
# <span style='font-family: "arial";'><br/></span></div>
# <div class="MsoNormal" style="line-height: 24px;">
# <span style='font-family: "arial";'><span style="color: red; font-family: arial, helvetica, sans-serif; text-indent: -24px;">(A) </span>Under Exhibition </span><br/>
# <span style='font-family: "arial";'><span style="color: red; font-family: arial, helvetica, sans-serif; text-indent: -24px;">(B) </span>Unknown Exhibition<o:p></o:p></span></div>
# <div class="MsoNormal" style="line-height: 24px;">
# <span style='font-family: "arial";'><span style="color: red; font-family: arial, helvetica, sans-serif; text-indent: -24px;">(C) </span>Universal Exhibition </span><br/>
# ...
